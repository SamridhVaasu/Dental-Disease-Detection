# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dental-diseases/README.dataset.txt
# /kaggle/input/dental-diseases/README.roboflow.txt
# /kaggle/input/dental-diseases/data.yaml
# /kaggle/input/dental-diseases/valid/labels/3991590000-jpg_png_jpg.rf.5340965eabfcde39e539ae26e4fc6974.txt
# /kaggle/input/dental-diseases/valid/labels/0f242450-GHASEMI_MARYAM_2020-08-01173228_jpg.rf.52df200174cb5ce89e890ac2e34c633f.txt
# /kaggle/input/dental-diseases/valid/labels/3195610000-jpg_png_jpg.rf.872012690c89b39462cea9e8bfae795f.txt
# /kaggle/input/dental-diseases/valid/labels/3759020000-jpg_png_jpg.rf.a4e8f1db8691c6bfc547be7331013ad3.txt
# /kaggle/input/dental-diseases/valid/labels/ffa16c16-Hoseyni_Habibe_48yo_31052021_130138_jpg.rf.f144173fa3c827d6f17897316f1eecd5.txt
# /kaggle/input/dental-diseases/valid/labels/3379990000-jpg_png_jpg.rf.7d749c04041c4c63beecfa8f963cc681.txt
# /kaggle/input/dental-diseases/valid/labels/3989690000-jpg_png_jpg.rf.7f18481998993ad942f6dabf5dff5ce3.txt
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 25.4 MB/s eta 0:00:0000:01
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# !yolo detect train data=/kaggle/input/dental-diseases/data.yaml model=yolo11x.pt epochs=50  imgsz=640

# %%
# !yolo detect train data=/kaggle/input/dental-diseases/data.yaml model=yolo11s-obb.pt epochs=30 imgsz=640 batch=16 workers=2 device=0
# Out:
# WARNING ⚠️ conflicting 'task=detect' passed with 'task=obb' model. Ignoring 'task=detect' and updating to 'task=obb' to match model.
# Ultralytics 8.3.71 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
# !zip -r train.zip /kaggle/working/runs/obb/train3
# Out:
# updating: kaggle/working/runs/obb/train3/ (stored 0%)
# updating: kaggle/working/runs/obb/train3/labels.jpg (deflated 27%)
# updating: kaggle/working/runs/obb/train3/confusion_matrix_normalized.png (deflated 18%)
# updating: kaggle/working/runs/obb/train3/val_batch2_labels.jpg (deflated 9%)
# updating: kaggle/working/runs/obb/train3/train_batch0.jpg (deflated 1%)
# updating: kaggle/working/runs/obb/train3/F1_curve.png (deflated 5%)
# updating: kaggle/working/runs/obb/train3/weights/ (stored 0%)
# updating: kaggle/working/runs/obb/train3/weights/last.pt (deflated 8%)
# updating: kaggle/working/runs/obb/train3/weights/best.pt (deflated 8%)
# updating: kaggle/working/runs/obb/train3/P_curve.png (deflated 6%)
# updating: kaggle/working/runs/obb/train3/val_batch0_pred.jpg (deflated 7%)
# updating: kaggle/working/runs/obb/train3/val_batch1_pred.jpg (deflated 7%)
# updating: kaggle/working/runs/obb/train3/train_batch2.jpg (deflated 1%)
# ...

# %%
from ultralytics import YOLO

model = YOLO('/kaggle/working/runs/obb/train3/weights/best.pt')
results = model.val()
# Out:
# Ultralytics 8.3.71 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# YOLO11s-obb summary (fused): 257 layers, 9,703,431 parameters, 0 gradients, 22.3 GFLOPs
# val: Scanning /kaggle/input/dental-diseases/valid/labels... 1953 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1953/1953 [00:03<00:00, 533.25it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/dental-diseases/valid is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 123/123 [00:31<00:00,  3.85it/s]
#                    all       1953      18170      0.672      0.595      0.581      0.364
#                 Caries        391       1375       0.63      0.322      0.403      0.185
#                  Crown        543       1363       0.74      0.957      0.867      0.708
#                Filling       1417       7054      0.734      0.784      0.784      0.452
# ...
